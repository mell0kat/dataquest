# %% [markdown]
# ## The Data
# We'll be working with a dataset from Germany's eBay website.  The dataset includes used cars.

# %%
import pandas as pd
import numpy as np

# %%
try:
    autos = pd.read_csv('autos.csv')
except:
    try:
        autos = pd.read_csv('autos.csv', encoding='Latin-1')
        print('Using Latin1 encoding')
    except:
        autos = pd.read_csv('autos.csv', encoding='Windows-1252')
        print('Using windows encoding')
# Out:
# Using Latin1 encoding

# %%
autos
# Out:
#                dateCrawled                                               name  \
# 0      2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3      2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# 5      2016-03-21 13:47:45  Chrysler_Grand_Voyager_2.8_CRD_Aut.Limited_Sto...
# 6      2016-03-20 17:55:21  VW_Golf_III_GT_Special_Electronic_Green_Metall...
# 7      2016-03-16 18:55:19                               Golf_IV_1.9_TDI_90PS
# 8      2016-03-22 16:51:34                                         Seat_Arosa
# 9      2016-03-16 13:47:02          Renault_Megane_Scenic_1.6e_RT_Klimaanlage
# 10     2016-03-15 01:41:36                       VW_Golf_Tuning_in_siber/grau
# ...

# %%
autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 20 columns):
# dateCrawled            50000 non-null object
# name                   50000 non-null object
# seller                 50000 non-null object
# offerType              50000 non-null object
# price                  50000 non-null object
# abtest                 50000 non-null object
# vehicleType            44905 non-null object
# yearOfRegistration     50000 non-null int64
# gearbox                47320 non-null object
# powerPS                50000 non-null int64
# model                  47242 non-null object
# odometer               50000 non-null object
# monthOfRegistration    50000 non-null int64
# fuelType               45518 non-null object
# brand                  50000 non-null object
# notRepairedDamage      40171 non-null object
# dateCreated            50000 non-null object
# nrOfPictures           50000 non-null int64
# ...

# %%
autos.head()
# Out:
#            dateCrawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offerType   price   abtest vehicleType  yearOfRegistration  \
# 0  privat   Angebot  $5,000  control         bus                2004
# 1  privat   Angebot  $8,500  control   limousine                1997
# 2  privat   Angebot  $8,990     test   limousine                2009
# 3  privat   Angebot  $4,350  control  kleinwagen                2007
# 4  privat   Angebot  $1,350     test       kombi                2003
#
#      gearbox  powerPS   model   odometer  monthOfRegistration fuelType  \
# ...

# %% [markdown]
# ### Data attributes
# * The dataset contains both numerical and string values, and there are several columns with missing values.The dataset contains 20 columns, most of which are strings.
# * Some columns have null values, but none have more than ~20% null values.
# * The column names use camelcase instead of Python's preferred snakecase, which means we can't just replace spaces with underscores.

# %%
autos.columns
# Out:
# Index(['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
#        'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS', 'model',
#        'odometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage', 'dateCreated', 'nrOfPictures', 'postalCode',
#        'lastSeen'],
#       dtype='object')

# %%
new_columns = ['date_crawled', 'name', 'seller', 'offer_type', 'price', 'abtest',
'vehicle_type', 'registration_year', 'gearbox', 'powerPS', 'model',
'odometer', 'registration_month', 'fuel_type', 'brand',
'unrepaired_damage', 'ad_created', 'nr_of_pictures', 'postal_code',
'last_seen']
autos.columns = new_columns
autos.head()
# Out:
#           date_crawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offer_type   price   abtest vehicle_type  registration_year  \
# 0  privat    Angebot  $5,000  control          bus               2004
# 1  privat    Angebot  $8,500  control    limousine               1997
# 2  privat    Angebot  $8,990     test    limousine               2009
# 3  privat    Angebot  $4,350  control   kleinwagen               2007
# 4  privat    Angebot  $1,350     test        kombi               2003
#
#      gearbox  powerPS   model   odometer  registration_month fuel_type  \
# ...

# %% [markdown]
# ### Step 1
# Changed column names from camelCase to snake_case

# %%
autos.describe(include='all')
# Out:
#                date_crawled         name  seller offer_type  price abtest  \
# count                 50000        50000   50000      50000  50000  50000
# unique                48213        38754       2          2   2357      2
# top     2016-03-30 17:37:35  Ford_Fiesta  privat    Angebot     $0   test
# freq                      3           78   49999      49999   1421  25756
# mean                    NaN          NaN     NaN        NaN    NaN    NaN
# std                     NaN          NaN     NaN        NaN    NaN    NaN
# min                     NaN          NaN     NaN        NaN    NaN    NaN
# 25%                     NaN          NaN     NaN        NaN    NaN    NaN
# 50%                     NaN          NaN     NaN        NaN    NaN    NaN
# 75%                     NaN          NaN     NaN        NaN    NaN    NaN
# max                     NaN          NaN     NaN        NaN    NaN    NaN
#
#        vehicle_type  registration_year  gearbox       powerPS  model  \
# ...

# %% [markdown]
# #### Cells with mostly one value that may be dropped:
# * seller
# * offer_type
#
# #### Columns that need more investigation:
#
# #### Numerical columns currently stored as text:
# * Price
# * Odometer

# %% [markdown]
# ### Step 2
# * Convert price and odometer columns to numerical values

# %%
autos['price'].unique()
# Out:
# array(['$5,000', '$8,500', '$8,990', ..., '$385', '$22,200', '$16,995'],
#       dtype=object)

# %%
autos['price'] = autos['price'].str.replace('$', '').str.replace(',','').astype(int)

# %%
autos['odometer'].unique()
# Out:
# array(['150,000km', '70,000km', '50,000km', '80,000km', '10,000km',
#        '30,000km', '125,000km', '90,000km', '20,000km', '60,000km',
#        '5,000km', '100,000km', '40,000km'], dtype=object)

# %%
autos['odometer'].size
# Out:
# 50000

# %%
autos['odometer'].str.contains('km').size
# Out:
# 50000

# %%
autos['odometer'] = (
    autos['odometer']
    .str.replace('km', '')
    .str.replace(',','').astype(int))

# %%
autos.rename(columns = { 'odometer': 'odometer_km'}, inplace=True)

# %%
autos.head()
# Out:
#           date_crawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offer_type  price   abtest vehicle_type  registration_year  \
# 0  privat    Angebot   5000  control          bus               2004
# 1  privat    Angebot   8500  control    limousine               1997
# 2  privat    Angebot   8990     test    limousine               2009
# 3  privat    Angebot   4350  control   kleinwagen               2007
# 4  privat    Angebot   1350     test        kombi               2003
#
#      gearbox  powerPS   model  odometer_km  registration_month fuel_type  \
# ...

# %%
price_min = autos['price'].min()
price_max = autos['price'].max()
price_unique = autos['price'].unique().shape
price_describe = autos['price'].describe()
price_counts = autos['price'].value_counts().sort_index(ascending=True)

# %%
print(price_min, price_max)
# Out:
# 0 99999999

# %%
price_unique
# Out:
# (2357,)

# %%
price_describe
# Out:
# count    5.000000e+04
# mean     9.840044e+03
# std      4.811044e+05
# min      0.000000e+00
# 25%      1.100000e+03
# 50%      2.950000e+03
# 75%      7.200000e+03
# max      1.000000e+08
# Name: price, dtype: float64

# %%
price_counts
# Out:
# 0           1421
# 1            156
# 2              3
# 3              1
# 5              2
# 8              1
# 9              1
# 10             7
# 11             2
# 12             3
# 13             2
# 14             1
# 15             2
# 17             3
# 18             1
# 20             4
# 25             5
# 29             1
# 30             7
# 35             1
# 40             6
# 45             4
# 47             1
# 49             4
# 50            49
# 55             2
# 59             1
# 60             9
# 65             5
# 66             1
#             ...
# 151990         1
# 155000         1
# 163500         1
# 163991         1
# 169000         1
# 169999         1
# 175000         1
# 180000         1
# 190000         1
# 194000         1
# 197000         1
# 198000         1
# 220000         1
# 250000         1
# 259000         1
# 265000         1
# 295000         1
# 299000         1
# 345000         1
# 350000         1
# 999990         1
# ...

# %% [markdown]
# ### Step 3
# * Remove outliers for price and odometer_km columns
# * Use > std away from mean as definition of outlier

# %%
price_outliers = autos[np.abs(autos['price'] - autos['price'].mean()) > (3*autos['price'].std())]
price_outliers
# Out:
#               date_crawled                                               name  \
# 2897   2016-03-12 21:50:57   Escort_MK_1_Hundeknochen_zum_umbauen_auf_RS_2000
# 11137  2016-03-29 23:52:57  suche_maserati_3200_gt_Zustand_unwichtig_laufe...
# 24384  2016-03-21 13:57:51                            Schlachte_Golf_3_gt_tdi
# 27371  2016-03-09 15:45:47                                         Fiat_Punto
# 39377  2016-03-08 23:53:51                        Tausche_volvo_v40_gegen_van
# 39705  2016-03-22 14:58:27                        Tausch_gegen_gleichwertiges
# 42221  2016-03-08 20:39:05                                  Leasinguebernahme
# 47598  2016-03-31 18:56:54  Opel_Vectra_B_1_6i_16V_Facelift_Tuning_Showcar...
# 47634  2016-04-04 21:25:21                                        Ferrari_FXX
#
#        seller offer_type     price   abtest vehicle_type  registration_year  \
# 2897   privat    Angebot  11111111     test    limousine               1973
# ...

# %%
autos = autos[np.abs(autos['price'] - autos['price'].mean()) <= (3*autos['price'].std())]
autos.shape
# Out:
# (49991, 20)

# %%
odo_min = autos['odometer_km'].min()
odo_max = autos['odometer_km'].max()
odo_unique = autos['odometer_km'].unique().shape
odo_describe = autos['odometer_km'].describe()
odo_counts = autos['odometer_km'].value_counts().sort_index(ascending=True)

# %%
print(odo_min, odo_max)
# Out:
# 5000 150000

# %%
odo_unique
# Out:
# (13,)

# %%
odo_describe
# Out:
# count     49991.000000
# mean     125736.432558
# std       40038.005358
# min        5000.000000
# 25%      125000.000000
# 50%      150000.000000
# 75%      150000.000000
# max      150000.000000
# Name: odometer_km, dtype: float64

# %%
odo_counts
# Out:
# 5000        966
# 10000       264
# 20000       784
# 30000       789
# 40000       818
# 50000      1026
# 60000      1164
# 70000      1230
# 80000      1436
# 90000      1757
# 100000     2168
# 125000     5170
# 150000    32419
# Name: odometer_km, dtype: int64

# %%
odo_outliers = autos[np.abs(autos['odometer_km'] - autos['odometer_km'].mean()) > (3*autos['odometer_km'].std())]

# %%
odo_outliers = autos[np.abs(autos['odometer_km'] - autos['odometer_km'].mean()) > (3*autos['odometer_km'].std())]

# %%
autos = autos[np.abs(autos['odometer_km'] - autos['odometer_km'].mean()) <= (3*autos['odometer_km'].std())]
autos.shape
# Out:
# (49025, 20)

# %% [markdown]
# ### Step 4
# * Dealing with date columns

# %%
autos[['date_crawled','ad_created','last_seen']][0:5]
# Out:
#           date_crawled           ad_created            last_seen
# 0  2016-03-26 17:47:46  2016-03-26 00:00:00  2016-04-06 06:45:54
# 1  2016-04-04 13:38:56  2016-04-04 00:00:00  2016-04-06 14:45:08
# 2  2016-03-26 18:57:24  2016-03-26 00:00:00  2016-04-06 20:15:37
# 3  2016-03-12 16:58:10  2016-03-12 00:00:00  2016-03-15 03:16:28
# 4  2016-04-01 14:38:50  2016-04-01 00:00:00  2016-04-01 14:38:50

# %%
autos['date_crawled'].str[:10].value_counts(normalize = True, dropna = False).sort_index()
# Out:
# 2016-03-05    0.025395
# 2016-03-06    0.014013
# 2016-03-07    0.036022
# 2016-03-08    0.033432
# 2016-03-09    0.033248
# 2016-03-10    0.032126
# 2016-03-11    0.032534
# 2016-03-12    0.036981
# 2016-03-13    0.015502
# 2016-03-14    0.036512
# 2016-03-15    0.034064
# 2016-03-16    0.029271
# 2016-03-17    0.031351
# 2016-03-18    0.012973
# 2016-03-19    0.034880
# 2016-03-20    0.037879
# 2016-03-21    0.037654
# 2016-03-22    0.032779
# 2016-03-23    0.032473
# 2016-03-24    0.028985
# 2016-03-25    0.031841
# 2016-03-26    0.032432
# 2016-03-27    0.030964
# 2016-03-28    0.034635
# 2016-03-29    0.034166
# 2016-03-30    0.033636
# 2016-03-31    0.031861
# 2016-04-01    0.033983
# 2016-04-02    0.035431
# 2016-04-03    0.038674
# 2016-04-04    0.036532
# 2016-04-05    0.013177
# 2016-04-06    0.003162
# 2016-04-07    0.001428
# Name: date_crawled, dtype: float64

# %% [markdown]
# * date_crawled spans March and April in 2016

# %%
autos['ad_created'].str[:10].value_counts(normalize = True, dropna = False).sort_index()
# Out:
# 2015-06-11    0.000020
# 2015-08-10    0.000020
# 2015-09-09    0.000020
# 2015-11-10    0.000020
# 2015-12-05    0.000020
# 2015-12-30    0.000020
# 2016-01-03    0.000020
# 2016-01-07    0.000020
# 2016-01-10    0.000041
# 2016-01-13    0.000020
# 2016-01-14    0.000020
# 2016-01-16    0.000020
# 2016-01-22    0.000020
# 2016-01-27    0.000061
# 2016-01-29    0.000020
# 2016-02-01    0.000020
# 2016-02-02    0.000041
# 2016-02-05    0.000041
# 2016-02-07    0.000020
# 2016-02-08    0.000020
# 2016-02-09    0.000041
# 2016-02-11    0.000020
# 2016-02-12    0.000061
# 2016-02-14    0.000041
# 2016-02-16    0.000020
# 2016-02-17    0.000020
# 2016-02-18    0.000041
# 2016-02-19    0.000061
# 2016-02-20    0.000041
# 2016-02-21    0.000061
#                 ...
# 2016-03-09    0.033269
# 2016-03-10    0.031902
# 2016-03-11    0.032820
# 2016-03-12    0.036798
# 2016-03-13    0.016889
# 2016-03-14    0.035084
# 2016-03-15    0.033840
# 2016-03-16    0.029781
# 2016-03-17    0.031045
# ...

# %% [markdown]
# * ad_created spans June 2015 - April 2016

# %%
autos['last_seen'].str[:10].value_counts(normalize = True, dropna = False).sort_index()
# Out:
# 2016-03-05    0
# %%
autos['brand'].unique()
# Out:
# array(['peugeot', 'bmw', 'volkswagen', 'smart', 'ford', 'chrysler',
#        'seat', 'renault', 'mercedes_benz', 'audi', 'sonstige_autos',
#        'opel', 'mazda', 'porsche', 'mini', 'toyota', 'dacia', 'nissan',
#        'jeep', 'saab', 'volvo', 'mitsubishi', 'jaguar', 'fiat', 'skoda',
#        'subaru', 'kia', 'citroen', 'chevrolet', 'hyundai', 'honda',
#        'daewoo', 'suzuki', 'trabant', 'land_rover', 'alfa_romeo', 'lada',
#        'rover', 'daihatsu', 'lancia'], dtype=object)

# %%
most_freq_brands = autos['brand'].value_counts(normalize=True)[autos['brand'].value_counts(normalize=True)>0.05].index

# %%
mean_price_by_brand = {}
for brand in most_freq_brands:
    autos_for_brand = autos[autos['brand'] == brand]
    mean_price_by_brand[brand] = autos_for_brand['price'].mean()
mean_price_by_brand
# Out:
# {'audi': 8929.864794714487,
#  'bmw': 8255.411102775694,
#  'ford': 3862.7415005861667,
#  'mercedes_benz': 8370.421831438987,
#  'opel': 2830.290745597602,
#  'volkswagen': 5373.085755121487}

# %% [markdown]
# ### Aggregating price by brand for most frequest brands
# * Audi, bmw, mercedes are expensive brands, each with average used auto price > $8000
# * VW is mid-range, whereas Ford and Opel are more affordable

# %%
mean_mileage_by_brand = {}
for brand in most_freq_brands:
    autos_for_brand = autos[autos['brand'] == brand]
    mean_mileage_by_brand[brand] = autos_for_brand['odometer_km'].mean()
mean_mileage_by_brand
# Out:
# {'audi': 130967.43747050496,
#  'bmw': 134840.58514628658,
#  'ford': 126458.08909730363,
#  'mercedes_benz': 132769.6761741368,
#  'opel': 132133.75796178344,
#  'volkswagen': 131208.19437827537}

# %%
mean_price_by_brand_series = pd.Series(mean_price_by_brand)
mean_price_by_brand_series
# Out:
# audi             8929.864795
# bmw              8255.411103
# ford             3862.741501
# mercedes_benz    8370.421831
# opel             2830.290746
# volkswagen       5373.085755
# dtype: float64

# %%
mean_mileage_by_brand_series = pd.Series(mean_mileage_by_brand)
mean_mileage_by_brand_series
# Out:
# audi             130967.437471
# bmw              134840.585146
# ford             126458.089097
# mercedes_benz    132769.676174
# opel             132133.757962
# volkswagen       131208.194378
# dtype: float64

# %%
mean_price_by_brand_df = pd.DataFrame(mean_price_by_brand_series, columns=['mean_price'])

# %%
mean_price_by_brand_df['mean_mileage'] = mean_mileage_by_brand_series
mean_price_by_brand_df
# Out:
#                 mean_price   mean_mileage
# audi           8929.864795  130967.437471
# bmw            8255.411103  134840.585146
# ford           3862.741501  126458.089097
# mercedes_benz  8370.421831  132769.676174
# opel           2830.290746  132133.757962
# volkswagen     5373.085755  131208.194378

# %% [markdown]
# ### Aggregating price and mileage by brand
#     * The top brands have approximately the same mileage
#     * Mileage oes not appear to have any significant effect on price

# %% [markdown]
# ## Next Steps
# * Data cleaning next steps:
#   * Identify categorical data that uses german words, translate them and map the values to their english counterparts
#   * Convert the dates to be uniform numeric data, so "2016-03-21" becomes the integer 20160321.
#   * See if there are particular keywords in the name column that you can extract as new columns
# * Analysis next steps
#   * Find the most common brand/model combinations
#   * Split the odometer_km into groups, and use aggregation to see if average prices follows any patterns based on the milage.
#   * How much cheaper are cars with damage than their non-damaged counterparts?
